# %%
import json
import pandas as pd

# %%
#loaded the cleaned data
with open('/Users/yimengliu/Documents/Erdos_Institute/mgp/summer26-math-genealogy/data/raw/data-new.json',"r") as file:
    tree=json.load(file)

# %%
nodes=pd.DataFrame(tree["nodes"])

# %%
nodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338532 entries, 0 to 338531
# Data columns (total 8 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   name      338526 non-null  object
#  1   thesis    307400 non-null  object
#  2   school    281806 non-null  object
#  3   country   322986 non-null  object
#  4   year      277237 non-null  float64
#  5   subject   202492 non-null  object
#  6   advisors  338532 non-null  object
#  7   students  338532 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 20.7+ MB

# %%
nodes.head(15)
# Out:
#                        name  \
# 0   Ernest Willard Anderson
# 1             Archie Higdon
# 2          Donald Hill Rock
# 3     Charles Joseph Thorne
# 4         Ralph Harry Tripp
# 5         William B. Stiles
# 6       Carl Eric Langenhop
# 7            James W. Beach
# 8         Henry David Block
# 9           Frank E. Bortle
# 10    Alfred E. Engelbrecht
# 11     Robert Nicholas Goss
# 12    Lawrence Edward Payne
# 13              Jun Tsu Chu
# 14      Roy Franklin Reeves
#
#                                                thesis                 school  \
# 0   Statics of Special Types of Homogeneous Elasti...  Iowa State University
# 1     Stresses in Moderately Thick Rectangular Plates  Iowa State University
# 2            Finite Strain Analysis in Elastic Theory  Iowa State University
# 3   The Approximate Solution of Linear Differentia...  Iowa State University
# 4   Statical Equilibrium of Skew and Sector-Shaped...  Iowa State University
# ...

# %%
nodes.iloc[258]
# Out:
# name                                       Dean L. Isaacson
# thesis                                                 None
# school                University of Minnesota - Twin Cities
# country                                        UnitedStates
# year                                                 1968.0
# subject                                                None
# advisors                                                 []
# students                                         [152, 166]
# number_of_students                                        2
# Name: 258, dtype: object

# %%
#add a new feature computing the number of students
nodes['number_of_students']=nodes['students'].apply(lambda x: len(x))
nodes['number_of_students'].describe()
# Out:
# count    338532.000000
# mean          1.132419
# std           3.996859
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         181.000000
# Name: number_of_students, dtype: float64

# %%
count= nodes['number_of_students'].value_counts().sort_index()
proportions=(nodes['number_of_students'].value_counts()/len(nodes)).sort_index()

result=pd.concat([count, proportions], axis=1, keys=['count','proportion'])

# %%
print(result)
# Out:
#                      count  proportion
# number_of_students
# 0                   255618    0.755078
# 1                    34759    0.102676
# 2                    12699    0.037512
# 3                     7313    0.021602
# 4                     4966    0.014669
# ...                    ...         ...
# 127                      1    0.000003
# 130                      1    0.000003
# 133                      1    0.000003
# 146                      1    0.000003
# 181                      1    0.000003
#
# [104 rows x 2 columns]

# %%
#find the missing id (they are already missing in the mgp database)
all_ids = set(range(1, nodes.index.max()+1))
existing_ids = set(nodes.index)

missing_ids = sorted(all_ids - existing_ids)

print("Number of missing IDs:", len(missing_ids))
print("First 20 missing IDs:", missing_ids[:20])
# Out:
# Number of missing IDs: 0
# First 20 missing IDs: []

# %%
nodes.index.max()
# Out:
# 338531
